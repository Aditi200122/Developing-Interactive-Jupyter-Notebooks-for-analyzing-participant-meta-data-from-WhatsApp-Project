# %% [markdown]
# This notebook help us visualize how many unique senders were active each day

# %%
import sys, os
sys.path.append(os.path.abspath("../"))  


from functions.active_contacts import *

# %% [markdown]
# Displays an interactive dashboard for active contacts:
# - Type donor id or select donor
# - Select Sent, Recieved or ALL
# - Select Start and end Date

# %%
show_active_chats_dashboard()

# %% [markdown]
# Each column = one day
#
# Each row = one conversation
#
# Color shows whether that chat was active on that day (sent, received, or both).
#
# The figure gives a temporal overview of how many chats were active and when.

# %% [markdown]
# - Type donor id or select donor
# - Select Start and end Date
# - Select from chat options( e.g, ALL Chats or individual Chat ID)
# - Select moving average value

# %%
show_daily_active_contacts_time_series_dashboard()

# %% [markdown]
# A rising trend suggests increasing engagement; a drop may indicate loss of participant interest.
