# %% [markdown]
# Shows total words sent in a day over time

# %%
import sys, os
sys.path.append(os.path.abspath("../"))  

from functions.active_contacts import *

# %% [markdown]
# Displays an interactive dashboard for Daily words analysis:
# - Select donor and click on Load button
# - Select from chat options( e.g, ALL Chats or individual Chat ID)
# - Select Start and end Date
# - Select moving average value

# %%
show_daily_words_heatmap_words_axis_dashboard()

# %%
show_daily_words_dashboard()

# %% [markdown]
# It reveals conversation intensity showing communication volume over time.
