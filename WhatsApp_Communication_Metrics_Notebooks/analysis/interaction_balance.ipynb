# %% [markdown]
# Interaction Balance measures how equally donor and contacts contribute to conversations

# %%
import sys, os
sys.path.append(os.path.abspath("../"))  

from functions.interaction import *

# %% [markdown]
# Displays an interactive dashboard for Interaction Balance analysis:
# - Type donor id or select donor
# - Select view Bias distribution or per chart word comparision

# %%
show_interaction_balance_dashboard()

# %% [markdown]
# Bias 0 means perfectly balanced interaction (equal contributions).
#
# Negative Bias means participant sent more.
#
#
# Positive Bias means contact sent more.
