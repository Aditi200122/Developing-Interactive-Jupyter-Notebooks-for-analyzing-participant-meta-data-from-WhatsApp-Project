# %% [markdown]
# Burstiness metric measures whether messages arrive at consistent intervals or in quick bursts.

# %%
import sys, os
sys.path.append(os.path.abspath("../"))  

from functions.burstiness import *

# %% [markdown]
# Displays an interactive dashboard for Burstiness analysis:
# - Type donor id or select donor from dropdown
# - Choose metric (from chat options i.e Overall (Aggregate B1), Overall (Dominant Behavior), Overall (Largest Absolute B1 Value) or individual chat ID )

# %% [markdown]
# Overall (Aggregate B1) show a raster that aggregates all donors days across all chats into a single set of days and compute an aggregate B1. Useful to see the donor's overall pattern.
#
# Overall (Dominant Behavior) finds classification counts across chats (how many Regular/Bursty/Random) and plots an example chat for the dominant class (or multiple if there is a tie).
#
#
# Overall (Largest Absolute B1 Value) finds the chat with the largest absolute B1 (most extreme).
#
# Single chat ID shows single set of days acrosss time.

# %%
show_raster_dashboard_overall()

# %% [markdown]
# Higher burstiness means messages are clustered into intense short conversations followed by silence where as lower burstiness values indicate consistent engagement.
