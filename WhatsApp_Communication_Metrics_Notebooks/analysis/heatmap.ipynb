# %% [markdown]
# This notebook visualizes when messaging activity occurs across days and hours using a heatmap representation

# %%
import sys, os
sys.path.append(os.path.abspath("../"))
from functions.Heatmap import *

# %% [markdown]
# Displays an interactive dashboard:
# - Type donor id or Select donor id
# - Select from chat options( e.g, ALL Chats or individual Chat ID)
# - Select Start and end Date
# - Select thresold value

# %%
show_words_heatmap_dashboard_dates()

# %% [markdown]
# The heatmap shows how intensity changes over time, where the threshold (e.g., 5 words/hour) determines what is considered “active”. Dark/Empty means No or very few words/messages. Bright yellow means High activity (above threshold).
